# %%
from yahooquery import Screener

s = Screener()
data = s.get_screeners('all_cryptocurrencies_us', count=250)

# data is in the quotes key
dicts = data['all_cryptocurrencies_us']['quotes']
symbols = [d['symbol'] for d in dicts]
symbols
# Out:
# ['BTC-USD',
#  'ETH-USD',
#  'USDT-USD',
#  'USDC-USD',
#  'BNB-USD',
#  'BUSD-USD',
#  'XRP-USD',
#  'ADA-USD',
#  'SOL-USD',
#  'DOGE-USD',
#  'DOT-USD',
#  'DAI-USD',
#  'MATIC-USD',
#  'WTRX-USD',
#  'SHIB-USD',
#  'TRX-USD',
#  'HEX-USD',
#  'AVAX-USD',
#  'WBTC-USD',
#  'STETH-USD',
#  'LEO-USD',
#  'ATOM-USD',
#  'YOUC-USD',
#  'UNI1-USD',
#  'ETC-USD',
#  'LTC-USD',
#  'LINK-USD',
#  'FTT-USD',
#  'NEAR-USD',
#  'XLM-USD',
#  'CRO-USD',
#  'XMR-USD',
#  'ALGO-USD',
#  'BCH-USD',
#  'BTCB-USD',
#  'LUNA1-USD',
#  'TONCOIN-USD',
#  'APE3-USD',
#  'FLOW-USD',
#  'VET-USD',
#  'ICP-USD',
#  'FIL-USD',
#  'CHZ-USD',
#  'XTZ-USD',
#  'FRAX-USD',
#  'MANA-USD',
#  'HBAR-USD',
#  'XCN1-USD',
#  'QNT-USD',
#  'EOS-USD',
#  'SAND-USD',
#  'WBNB-USD',
#  'EGLD-USD',
#  'TUSD-USD',
#  'AAVE-USD',
#  'THETA-USD',
#  'AXS-USD',
#  'BIT1-USD',
#  'BSV-USD',
#  'USDP-USD',
#  'OKB-USD',
#  'KCS-USD',
#  'ZEC-USD',
#  'BTT-USD',
#  'HBTC-USD',
#  'BTT2-USD',
#  'XEC-USD',
#  'USDD-USD',
#  'MIOTA-USD',
#  'GRT1-USD',
#  'HT-USD',
#  'USDN-USD',
#  'CAKE-USD',
#  'MKR-USD',
#  'KLAY-USD',
#  'SNX-USD',
#  'NEO-USD',
#  'FTM-USD',
#  'HNT-USD',
#  'LDO-USD',
#  'RUNE-USD',
#  'PAXG-USD',
#  'CRV-USD',
#  'NEXO-USD',
#  'ENJ-USD',
#  'BAT-USD',
#  'GT-USD',
#  'DASH-USD',
#  'STX-USD',
#  'WAVES-USD',
#  'RVN-USD',
#  'ZIL-USD',
#  'DFI-USD',
#  'FEI-USD',
#  'LRC-USD',
#  'XAUT-USD',
#  'MINA-USD',
#  'TWT-USD',
#  'KAVA-USD',
#  'COMP1-USD',
#  'OSMO-USD',
#  'GMT3-USD',
#  'BTG-USD',
#  'XEM-USD',
#  'LUNA2-USD',
#  'CELO-USD',
#  'DCR-USD',
#  'CEL-USD',
#  'HOT1-USD',
#  '1INCH-USD',
#  'KSM-USD',
#  'MV-USD',
#  'UST-USD',
#  'GNO-USD',
#  'XDC-USD',
#  'CCXX-USD',
#  'AR-USD',
#  'CVX-USD',
#  'BNX-USD',
#  'YFI-USD',
#  'QTUM-USD',
#  'ANKR-USD',
#  'GALA-USD',
#  'GUSD-USD',
#  'NXM-USD',
#  'ROSE-USD',
#  'KDA-USD',
#  'GLM-USD',
#  'TFUEL-USD',
#  'ENS-USD',
#  'IOTX-USD',
#  'FLUX-USD',
#  'RPL-USD',
#  'BTRST-USD',
#  'FRTS-USD',
#  'T-USD',
#  'BAL-USD',
#  'KNC-USD',
#  'ZEON-USD',
#  'OMG-USD',
#  'ONE1-USD',
#  'EFI-USD',
#  'BORA-USD',
#  'ZRX-USD',
#  'BRISE-USD',
#  'RSR-USD',
#  'ICX-USD',
#  'HIVE-USD',
#  'JST-USD',
#  'LPT-USD',
#  'IOST-USD',
#  'WEMIX-USD',
#  'OP1-USD',
#  'XYM-USD',
#  'LN-USD',
#  'AMP-USD',
#  'SRM-USD',
#  'VGX-USD',
#  'STORJ-USD',
#  'ONT-USD',
#  'SAFEMOON-USD',
#  'SYN1-USD',
#  'WAXP-USD',
#  'AUDIO-USD',
#  'ERG-USD',
#  'GLMR-USD',
#  'SC-USD',
#  'SAFE1-USD',
#  'POLY-USD',
#  'IMX1-USD',
#  'MXC-USD',
#  'XCH-USD',
#  'ZEN-USD',
#  'LUSD-USD',
#  'ABBC-USD',
#  'CHSB-USD',
#  'SCRT-USD',
#  'CSPR-USD',
#  'SXP-USD',
#  'UMA-USD',
#  'WOO-USD',
#  'HUSD-USD',
#  'PLA3-USD',
#  'NFT1-USD',
#  'PUNDIX-USD',
#  'DGB-USD',
#  'SLP-USD',
#  'DAO-USD',
#  'SKL-USD',
#  'VVS-USD',
#  'ELON-USD',
#  'CKB-USD',
#  'ASTR-USD',
#  'SUSHI-USD',
#  'EPS1-USD',
#  'BABYDOGE-USD',
#  'CVC-USD',
#  'MED-USD',
#  'EWT-USD',
#  'KEEP-USD',
#  'HUM-USD',
#  'LSK-USD',
#  'UOS-USD',
#  'EURS-USD',
#  'SSV-USD',
#  'INJ-USD',
#  'RNDR-USD',
#  'SYS-USD',
#  'MAID-USD',
#  'ACA1-USD',
#  'CEEK-USD',
#  'PLTC-USD',
#  'PEOPLE-USD',
#  'BTCST-USD',
#  'SPELL-USD',
#  'CELR-USD',
#  'COTI-USD',
#  'REN-USD',
#  'VLX-USD',
#  'REQ-USD',
#  'NU-USD',
#  'ONG1-USD',
#  'XNO-USD',
#  'MVL-USD',
#  'METIS-USD',
#  'CFG-USD',
#  'WVLX-USD',
#  'USDX2-USD',
#  'VUSDC-USD',
#  'DLC2-USD',
#  'LOOKS-USD',
#  'RACA-USD',
#  'ORBS-USD',
#  'FX-USD',
#  'TRIBE-USD',
#  'ARDR-USD',
#  'RLC-USD',
#  'RKN-USD',
#  'SNT-USD',
#  'AVINOC-USD',
#  'OCEAN-USD',
#  'CFX-USD',
#  'UQC-USD',
#  'REEF-USD',
#  'POWR-USD',
#  'WIN-USD',
#  'PROM-USD',
#  'XYO-USD',
#  'HXRO-USD',
#  'NMR-USD']

# %%
import yfinance as yf
BTC_Ticker = yf.Ticker("BTC-USD")
BTC_Data = BTC_Ticker.history(period="max",interval='1d')
BTC_Data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2022-09-16  19704.005859  19870.628906  19400.076172  19772.583984
# 2022-09-17  19777.033203  20162.531250  19777.033203  20127.576172
# 2022-09-18  20127.234375  20127.234375  19387.492188  19419.505859
# 2022-09-19  19418.572266  19639.480469  18390.318359  19544.128906
# 2022-09-20  19573.447266  19592.896484  19241.068359  19460.785156
#
#                  Volume  Dividends  Stock Splits
# Date
# 2014-09-17     21056800          0             0
# 2014-09-18     34483200          0             0
# 2014-09-19     37919700          0             0
# 2014-09-20     36863600          0             0
# 2014-09-21     26580100          0             0
# ...                 ...        ...           ...
# 2022-09-16  30123362273          0             0
# 2022-09-17  24957448100          0             0
# 2022-09-18  31254779144          0             0
# 2022-09-19  40177002624          0             0
# 2022-09-20  35875958784          0             0
#
# [2926 rows x 7 columns]

# %%
symbols_fixed = []
for symbol in symbols:
    symbol = symbol.split('-')[0]
    symbols_fixed.append(symbol)
symbols_fixed
# Out:
# ['BTC',
#  'ETH',
#  'USDT',
#  'USDC',
#  'BNB',
#  'BUSD',
#  'XRP',
#  'ADA',
#  'SOL',
#  'DOGE',
#  'DOT',
#  'DAI',
#  'MATIC',
#  'WTRX',
#  'SHIB',
#  'TRX',
#  'HEX',
#  'AVAX',
#  'WBTC',
#  'STETH',
#  'LEO',
#  'YOUC',
#  'ATOM',
#  'UNI1',
#  'ETC',
#  'LTC',
#  'LINK',
#  'FTT',
#  'NEAR',
#  'XLM',
#  'CRO',
#  'XMR',
#  'ALGO',
#  'BCH',
#  'BTCB',
#  'LUNA1',
#  'TONCOIN',
#  'APE3',
#  'FLOW',
#  'VET',
#  'ICP',
#  'FIL',
#  'CHZ',
#  'XTZ',
#  'FRAX',
#  'MANA',
#  'HBAR',
#  'XCN1',
#  'QNT',
#  'SAND',
#  'EOS',
#  'WBNB',
#  'EGLD',
#  'TUSD',
#  'AAVE',
#  'THETA',
#  'AXS',
#  'BIT1',
#  'USDP',
#  'BSV',
#  'OKB',
#  'KCS',
#  'ZEC',
#  'BTT',
#  'HBTC',
#  'BTT2',
#  'XEC',
#  'USDD',
#  'MIOTA',
#  'GRT1',
#  'HT',
#  'USDN',
#  'MKR',
#  'CAKE',
#  'KLAY',
#  'SNX',
#  'NEO',
#  'HNT',
#  'FTM',
#  'LDO',
#  'RUNE',
#  'PAXG',
#  'CRV',
#  'NEXO',
#  'ENJ',
#  'BAT',
#  'GT',
#  'STX',
#  'DASH',
#  'RVN',
#  'WAVES',
#  'ZIL',
#  'DFI',
#  'FEI',
#  'XAUT',
#  'LRC',
#  'MINA',
#  'TWT',
#  'KAVA',
#  'OSMO',
#  'COMP1',
#  'GMT3',
#  'BTG',
#  'XEM',
#  'LUNA2',
#  'CELO',
#  'CEL',
#  'DCR',
#  'HOT1',
#  '1INCH',
#  'KSM',
#  'MV',
#  'UST',
#  'GNO',
#  'XDC',
#  'CVX',
#  'CCXX',
#  'AR',
#  'BNX',
#  'YFI',
#  'QTUM',
#  'ANKR',
#  'GUSD',
#  'GALA',
#  'NXM',
#  'KDA',
#  'ROSE',
#  'GLM',
#  'TFUEL',
#  'ENS',
#  'FRTS',
#  'IOTX',
#  'FLUX',
#  'RPL',
#  'BTRST',
#  'T',
#  'BAL',
#  'KNC',
#  'ZEON',
#  'OMG',
#  'ONE1',
#  'EFI',
#  'BRISE',
#  'BORA',
#  'ZRX',
#  'RSR',
#  'ICX',
#  'JST',
#  'HIVE',
#  'LPT',
#  'IOST',
#  'OP1',
#  'WEMIX',
#  'XYM',
#  'LN',
#  'AMP',
#  'SRM',
#  'VGX',
#  'STORJ',
#  'SYN1',
#  'ONT',
#  'SAFEMOON',
#  'WAXP',
#  'SAFE1',
#  'AUDIO',
#  'GLMR',
#  'ERG',
#  'SC',
#  'POLY',
#  'IMX1',
#  'MXC',
#  'ZEN',
#  'XCH',
#  'LUSD',
#  'CHSB',
#  'ABBC',
#  'SCRT',
#  'CSPR',
#  'SXP',
#  'UMA',
#  'WOO',
#  'HUSD',
#  'PLA3',
#  'PUNDIX',
#  'NFT1',
#  'DGB',
#  'DAO',
#  'SLP',
#  'SKL',
#  'VVS',
#  'ELON',
#  'CKB',
#  'ASTR',
#  'EPS1',
#  'SUSHI',
#  'CVC',
#  'BABYDOGE',
#  'MED',
#  'EWT',
#  'KEEP',
#  'HUM',
#  'UOS',
#  'EURS',
#  'LSK',
#  'SSV',
#  'INJ',
#  'RNDR',
#  'BTCST',
#  'MAID',
#  'ACA1',
#  'SYS',
#  'PLTC',
#  'CEEK',
#  'PEOPLE',
#  'SPELL',
#  'CELR',
#  'COTI',
#  'REQ',
#  'REN',
#  'VLX',
#  'NU',
#  'XNO',
#  'ONG1',
#  'MVL',
#  'CFG',
#  'METIS',
#  'WVLX',
#  'USDX2',
#  'VUSDC',
#  'DLC2',
#  'LOOKS',
#  'RACA',
#  'AVINOC',
#  'ORBS',
#  'FX',
#  'TRIBE',
#  'ARDR',
#  'RLC',
#  'SNT',
#  'RKN',
#  'UQC',
#  'OCEAN',
#  'REEF',
#  'POWR',
#  'WIN',
#  'XYO',
#  'HXRO',
#  'PROM',
#  'NMR',
#  'DENT']
