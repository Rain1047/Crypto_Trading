# %%
from yahooquery import Screener

s = Screener()
data = s.get_screeners('all_cryptocurrencies_us', count=250)

# data is in the quotes key
dicts = data['all_cryptocurrencies_us']['quotes']
symbols = [d['symbol'] for d in dicts]
symbols
# Out:
# ['BTC-USD',
#  'ETH-USD',
#  'USDT-USD',
#  'USDC-USD',
#  'BNB-USD',
#  'BUSD-USD',
#  'XRP-USD',
#  'ADA-USD',
#  'SOL-USD',
#  'DOGE-USD',
#  'DOT-USD',
#  'DAI-USD',
#  'MATIC-USD',
#  'WTRX-USD',
#  'SHIB-USD',
#  'TRX-USD',
#  'HEX-USD',
#  'AVAX-USD',
#  'WBTC-USD',
#  'STETH-USD',
#  'LEO-USD',
#  'YOUC-USD',
#  'UNI1-USD',
#  'ATOM-USD',
#  'ETC-USD',
#  'LTC-USD',
#  'LINK-USD',
#  'FTT-USD',
#  'NEAR-USD',
#  'XLM-USD',
#  'CRO-USD',
#  'XMR-USD',
#  'ALGO-USD',
#  'BCH-USD',
#  'BTCB-USD',
#  'LUNA1-USD',
#  'FLOW-USD',
#  'APE3-USD',
#  'TONCOIN-USD',
#  'VET-USD',
#  'ICP-USD',
#  'FIL-USD',
#  'XCN1-USD',
#  'CHZ-USD',
#  'FRAX-USD',
#  'XTZ-USD',
#  'EOS-USD',
#  'HBAR-USD',
#  'MANA-USD',
#  'SAND-USD',
#  'QNT-USD',
#  'WBNB-USD',
#  'EGLD-USD',
#  'TUSD-USD',
#  'AAVE-USD',
#  'THETA-USD',
#  'BIT1-USD',
#  'AXS-USD',
#  'USDP-USD',
#  'BSV-USD',
#  'OKB-USD',
#  'KCS-USD',
#  'BTT-USD',
#  'ZEC-USD',
#  'XEC-USD',
#  'HBTC-USD',
#  'BTT2-USD',
#  'MIOTA-USD',
#  'USDD-USD',
#  'HT-USD',
#  'GRT1-USD',
#  'USDN-USD',
#  'CAKE-USD',
#  'KLAY-USD',
#  'MKR-USD',
#  'HNT-USD',
#  'NEO-USD',
#  'FTM-USD',
#  'LDO-USD',
#  'SNX-USD',
#  'RUNE-USD',
#  'PAXG-USD',
#  'CRV-USD',
#  'NEXO-USD',
#  'ENJ-USD',
#  'GT-USD',
#  'BAT-USD',
#  'DASH-USD',
#  'STX-USD',
#  'WAVES-USD',
#  'ZIL-USD',
#  'DFI-USD',
#  'FEI-USD',
#  'RVN-USD',
#  'XAUT-USD',
#  'LRC-USD',
#  'MINA-USD',
#  'TWT-USD',
#  'COMP1-USD',
#  'KAVA-USD',
#  'GMT3-USD',
#  'BTG-USD',
#  'XEM-USD',
#  'CELO-USD',
#  'HOT1-USD',
#  'OSMO-USD',
#  'CEL-USD',
#  'MV-USD',
#  '1INCH-USD',
#  'DCR-USD',
#  'KSM-USD',
#  'LUNA2-USD',
#  'UST-USD',
#  'CCXX-USD',
#  'XDC-USD',
#  'GNO-USD',
#  'BNX-USD',
#  'AR-USD',
#  'CVX-USD',
#  'YFI-USD',
#  'QTUM-USD',
#  'GUSD-USD',
#  'GALA-USD',
#  'ANKR-USD',
#  'ROSE-USD',
#  'NXM-USD',
#  'KDA-USD',
#  'GLM-USD',
#  'FRTS-USD',
#  'ENS-USD',
#  'TFUEL-USD',
#  'BTRST-USD',
#  'IOTX-USD',
#  'RPL-USD',
#  'FLUX-USD',
#  'T-USD',
#  'ZEON-USD',
#  'ONE1-USD',
#  'OMG-USD',
#  'BAL-USD',
#  'EFI-USD',
#  'KNC-USD',
#  'BORA-USD',
#  'RSR-USD',
#  'ZRX-USD',
#  'SAFEMOON-USD',
#  'JST-USD',
#  'IOST-USD',
#  'LPT-USD',
#  'HIVE-USD',
#  'ICX-USD',
#  'BRISE-USD',
#  'WEMIX-USD',
#  'OP1-USD',
#  'AMP-USD',
#  'XYM-USD',
#  'LN-USD',
#  'SRM-USD',
#  'ONT-USD',
#  'SAFE1-USD',
#  'VGX-USD',
#  'STORJ-USD',
#  'POLY-USD',
#  'WAXP-USD',
#  'SC-USD',
#  'AUDIO-USD',
#  'GLMR-USD',
#  'IMX1-USD',
#  'SYN1-USD',
#  'XCH-USD',
#  'ZEN-USD',
#  'LUSD-USD',
#  'MXC-USD',
#  'ABBC-USD',
#  'ERG-USD',
#  'CSPR-USD',
#  'SXP-USD',
#  'CHSB-USD',
#  'UMA-USD',
#  'SCRT-USD',
#  'HUSD-USD',
#  'WOO-USD',
#  'PLA3-USD',
#  'NFT1-USD',
#  'SLP-USD',
#  'DAO-USD',
#  'DGB-USD',
#  'VVS-USD',
#  'SKL-USD',
#  'ELON-USD',
#  'CKB-USD',
#  'BABYDOGE-USD',
#  'SUSHI-USD',
#  'PUNDIX-USD',
#  'ASTR-USD',
#  'CVC-USD',
#  'MED-USD',
#  'KEEP-USD',
#  'LSK-USD',
#  'EURS-USD',
#  'HUM-USD',
#  'SSV-USD',
#  'RNDR-USD',
#  'UOS-USD',
#  'EWT-USD',
#  'SYS-USD',
#  'PLTC-USD',
#  'PEOPLE-USD',
#  'ACA1-USD',
#  'INJ-USD',
#  'CEEK-USD',
#  'MAID-USD',
#  'EPS1-USD',
#  'BTCST-USD',
#  'SPELL-USD',
#  'CELR-USD',
#  'REN-USD',
#  'NU-USD',
#  'XNO-USD',
#  'ONG1-USD',
#  'SWEAT-USD',
#  'MVL-USD',
#  'COTI-USD',
#  'USDX2-USD',
#  'VLX-USD',
#  'METIS-USD',
#  'VUSDC-USD',
#  'WIN-USD',
#  'REQ-USD',
#  'SNT-USD',
#  'CFG-USD',
#  'WVLX-USD',
#  'RKN-USD',
#  'RLC-USD',
#  'RACA-USD',
#  'AVINOC-USD',
#  'ORBS-USD',
#  'LOOKS-USD',
#  'ARDR-USD',
#  'FX-USD',
#  'OCEAN-USD',
#  'UQC-USD',
#  'POWR-USD',
#  'TRIBE-USD',
#  'REEF-USD',
#  'XYO-USD',
#  'EVER-USD',
#  'DENT-USD',
#  'HXRO-USD',
#  'WEVER-USD']

# %%
symbol_str = ''
for symbol in symbols:
    symbol_str = symbol_str + symbol + ' '
symbol_str
# Out:
# 'BTC-USD ETH-USD USDT-USD USDC-USD BNB-USD BUSD-USD XRP-USD ADA-USD SOL-USD DOGE-USD DOT-USD DAI-USD MATIC-USD WTRX-USD SHIB-USD TRX-USD HEX-USD AVAX-USD WBTC-USD STETH-USD LEO-USD YOUC-USD UNI1-USD ATOM-USD ETC-USD LTC-USD LINK-USD FTT-USD NEAR-USD XLM-USD CRO-USD XMR-USD ALGO-USD BCH-USD BTCB-USD LUNA1-USD FLOW-USD APE3-USD TONCOIN-USD VET-USD ICP-USD FIL-USD XCN1-USD CHZ-USD FRAX-USD XTZ-USD EOS-USD HBAR-USD MANA-USD SAND-USD QNT-USD WBNB-USD EGLD-USD TUSD-USD AAVE-USD THETA-USD BIT1-USD AXS-USD USDP-USD BSV-USD OKB-USD KCS-USD BTT-USD ZEC-USD XEC-USD HBTC-USD BTT2-USD MIOTA-USD USDD-USD HT-USD GRT1-USD USDN-USD CAKE-USD KLAY-USD MKR-USD HNT-USD NEO-USD FTM-USD LDO-USD SNX-USD RUNE-USD PAXG-USD CRV-USD NEXO-USD ENJ-USD GT-USD BAT-USD DASH-USD STX-USD WAVES-USD ZIL-USD DFI-USD FEI-USD RVN-USD XAUT-USD LRC-USD MINA-USD TWT-USD COMP1-USD KAVA-USD GMT3-USD BTG-USD XEM-USD CELO-USD HOT1-USD OSMO-USD CEL-USD MV-USD 1INCH-USD DCR-USD KSM-USD LUNA2-USD UST-USD CCXX-USD XDC-USD GNO-USD BNX-USD AR-USD CVX-USD YFI-USD QTUM-USD GUSD-USD GALA-USD ANKR-USD ROSE-USD NXM-USD KDA-USD GLM-USD FRTS-USD ENS-USD TFUEL-USD BTRST-USD IOTX-USD RPL-USD FLUX-USD T-USD ZEON-USD ONE1-USD OMG-USD BAL-USD EFI-USD KNC-USD BORA-USD RSR-USD ZRX-USD SAFEMOON-USD JST-USD IOST-USD LPT-USD HIVE-USD ICX-USD BRISE-USD WEMIX-USD OP1-USD AMP-USD XYM-USD LN-USD SRM-USD ONT-USD SAFE1-USD VGX-USD STORJ-USD POLY-USD WAXP-USD SC-USD AUDIO-USD GLMR-USD IMX1-USD SYN1-USD XCH-USD ZEN-USD LUSD-USD MXC-USD ABBC-USD ERG-USD CSPR-USD SXP-USD CHSB-USD UMA-USD SCRT-USD HUSD-USD WOO-USD PLA3-USD NFT1-USD SLP-USD DAO-USD DGB-USD VVS-USD SKL-USD ELON-USD CKB-USD BABYDOGE-USD SUSHI-USD PUNDIX-USD ASTR-USD CVC-USD MED-USD KEEP-USD LSK-USD EURS-USD HUM-USD SSV-USD RNDR-USD UOS-USD EWT-USD SYS-USD PLTC-USD PEOPLE-USD ACA1-USD INJ-USD CEEK-USD MAID-USD EPS1-USD BTCST-USD SPELL-USD CELR-USD REN-USD NU-USD XNO-USD ONG1-USD SWEAT-USD MVL-USD COTI-USD USDX2-USD VLX-USD METIS-USD VUSDC-USD WIN-USD REQ-USD SNT-USD CFG-USD WVLX-USD RKN-USD RLC-USD RACA-USD AVINOC-USD ORBS-USD LOOKS-USD ARDR-USD FX-USD OCEAN-USD UQC-USD POWR-USD TRIBE-USD REEF-USD XYO-USD EVER-USD DENT-USD HXRO-USD WEVER-USD '

# %%
symbol_str = 'BTC-USD ETH-USD USDT-USD USDC-USD BNB-USD BUSD-USD'

# %%
import yfinance as yf

data = yf.download(
    tickers = symbol_str, 
    period = '2y', 
    interval = '1d', 
    group_by = 'ticker', 
    threads = True,
)
data['BTC-USD']
# Out:
# [*********************100%***********************]  6 of 6 completed
#                     Open          High           Low         Close  \
# Date
# 2020-09-21  10934.925781  10988.304688  10380.260742  10462.259766
# 2020-09-22  10459.624023  10568.077148  10382.726562  10538.459961
# 2020-09-23  10535.492188  10537.828125  10197.865234  10246.186523
# 2020-09-24  10248.786133  10771.056641  10231.490234  10760.066406
# 2020-09-25  10761.109375  10777.696289  10578.914062  10692.716797
# ...                  ...           ...           ...           ...
# 2022-09-17  19777.033203  20162.531250  19777.033203  20127.576172
# 2022-09-18  20127.234375  20127.234375  19387.492188  19419.505859
# 2022-09-19  19418.572266  19639.480469  18390.318359  19544.128906
# 2022-09-20  19545.591797  19602.457031  18813.455078  18890.789062
# 2022-09-21  18883.615234  19092.328125  18883.615234  18936.775391
#
#                Adj Close       Volume
# Date
# 2020-09-21  10462.259766  28884999244
# 2020-09-22  10538.459961  23621787804
# 2020-09-23  10246.186523  23788661867
# 2020-09-24  10760.066406  47144380902
# 2020-09-25  10692.716797  39348590957
# ...                  ...          ...
# 2022-09-17  20127.576172  24957448100
# 2022-09-18  19419.505859  31254779144
# 2022-09-19  19544.128906  40177002624
# 2022-09-20  18890.789062  36791346508
# 2022-09-21  18936.775391  34790809600
#
# [731 rows x 6 columns]

# %%
df = data['BTC-USD']
df['datatime'] = df
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 df = data['BTC-USD']
# ----> 2 df['datatime'] = dfdf
#
# NameError: name 'dfdf' is not defined

# %%
import yfinance as yf
BTC_Ticker = yf.Ticker("BTC-USD")
BTC_Data = BTC_Ticker.history(period="max",interval='1d')
BTC_Data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2022-09-16  19704.005859  19870.628906  19400.076172  19772.583984
# 2022-09-17  19777.033203  20162.531250  19777.033203  20127.576172
# 2022-09-18  20127.234375  20127.234375  19387.492188  19419.505859
# 2022-09-19  19418.572266  19639.480469  18390.318359  19544.128906
# 2022-09-20  19573.447266  19592.896484  19241.068359  19460.785156
#
#                  Volume  Dividends  Stock Splits
# Date
# 2014-09-17     21056800          0             0
# 2014-09-18     34483200          0             0
# 2014-09-19     37919700          0             0
# 2014-09-20     36863600          0             0
# 2014-09-21     26580100          0             0
# ...                 ...        ...           ...
# 2022-09-16  30123362273          0             0
# 2022-09-17  24957448100          0             0
# 2022-09-18  31254779144          0             0
# 2022-09-19  40177002624          0             0
# 2022-09-20  35875958784          0             0
#
# [2926 rows x 7 columns]

# %%
from cryptocmd import CmcScraper

# initialise scraper without time interval for max historical data
scraper = CmcScraper("BTC")
# Pandas dataFrame for the same data
df = scraper.get_dataframe()
df
# Out:
#            Date          Open          High           Low         Close  \
# 0    2022-09-20  19545.591275  19602.456746  18813.455011  18890.789096
# 1    2022-09-19  19418.571422  19639.479733  18390.318710  19544.129250
# 2    2022-09-18  20127.233948  20127.233948  19387.491348  19419.506191
# 3    2022-09-17  19777.034028  20162.532022  19777.034028  20127.576657
# 4    2022-09-16  19704.005441  19870.629766  19400.075449  19772.584206
# ...         ...           ...           ...           ...           ...
# 3428 2013-05-02    116.379997    125.599998     92.281898    105.209999
# 3429 2013-05-01    139.000000    139.889999    107.720001    116.989998
# 3430 2013-04-30    144.000000    146.929993    134.050003    139.000000
# 3431 2013-04-29    134.444000    147.488007    134.000000    144.539993
# 3432 2013-04-28    135.300003    135.979996    132.100006    134.210007
#
#             Volume    Market Cap
# 0     3.679135e+10  3.618764e+11
# 1     4.017700e+10  3.743735e+11
# 2     3.125478e+10  3.719704e+11
# 3     2.495745e+10  3.855133e+11
# 4     3.012336e+10  3.786932e+11
# ...            ...           ...
# 3428  0.000000e+00  1.168517e+09
# 3429  0.000000e+00  1.298955e+09
# 3430  0.000000e+00  1.542813e+09
# 3431  0.000000e+00  1.603769e+09
# 3432  0.000000e+00  1.488567e+09
#
# [3433 rows x 7 columns]

# %%
symbols_fixed = []
for symbol in symbols:
    symbol = symbol.split('-')[0]
    symbols_fixed.append(symbol)
symbols_fixed
# Out:
# ['BTC',
#  'ETH',
#  'USDT',
#  'USDC',
#  'BNB',
#  'BUSD',
#  'XRP',
#  'ADA',
#  'SOL',
#  'DOGE',
#  'DOT',
#  'DAI',
#  'MATIC',
#  'WTRX',
#  'SHIB',
#  'TRX',
#  'HEX',
#  'AVAX',
#  'WBTC',
#  'STETH',
#  'LEO',
#  'YOUC',
#  'ATOM',
#  'UNI1',
#  'ETC',
#  'LTC',
#  'LINK',
#  'FTT',
#  'NEAR',
#  'XLM',
#  'CRO',
#  'XMR',
#  'ALGO',
#  'BCH',
#  'BTCB',
#  'LUNA1',
#  'TONCOIN',
#  'APE3',
#  'FLOW',
#  'VET',
#  'ICP',
#  'FIL',
#  'CHZ',
#  'XTZ',
#  'FRAX',
#  'MANA',
#  'HBAR',
#  'XCN1',
#  'QNT',
#  'SAND',
#  'EOS',
#  'WBNB',
#  'EGLD',
#  'TUSD',
#  'AAVE',
#  'THETA',
#  'AXS',
#  'BIT1',
#  'USDP',
#  'BSV',
#  'OKB',
#  'KCS',
#  'ZEC',
#  'BTT',
#  'HBTC',
#  'BTT2',
#  'XEC',
#  'USDD',
#  'MIOTA',
#  'GRT1',
#  'HT',
#  'USDN',
#  'MKR',
#  'CAKE',
#  'KLAY',
#  'SNX',
#  'NEO',
#  'HNT',
#  'FTM',
#  'LDO',
#  'RUNE',
#  'PAXG',
#  'CRV',
#  'NEXO',
#  'ENJ',
#  'BAT',
#  'GT',
#  'STX',
#  'DASH',
#  'RVN',
#  'WAVES',
#  'ZIL',
#  'DFI',
#  'FEI',
#  'XAUT',
#  'LRC',
#  'MINA',
#  'TWT',
#  'KAVA',
#  'OSMO',
#  'COMP1',
#  'GMT3',
#  'BTG',
#  'XEM',
#  'LUNA2',
#  'CELO',
#  'CEL',
#  'DCR',
#  'HOT1',
#  '1INCH',
#  'KSM',
#  'MV',
#  'UST',
#  'GNO',
#  'XDC',
#  'CVX',
#  'CCXX',
#  'AR',
#  'BNX',
#  'YFI',
#  'QTUM',
#  'ANKR',
#  'GUSD',
#  'GALA',
#  'NXM',
#  'KDA',
#  'ROSE',
#  'GLM',
#  'TFUEL',
#  'ENS',
#  'FRTS',
#  'IOTX',
#  'FLUX',
#  'RPL',
#  'BTRST',
#  'T',
#  'BAL',
#  'KNC',
#  'ZEON',
#  'OMG',
#  'ONE1',
#  'EFI',
#  'BRISE',
#  'BORA',
#  'ZRX',
#  'RSR',
#  'ICX',
#  'JST',
#  'HIVE',
#  'LPT',
#  'IOST',
#  'OP1',
#  'WEMIX',
#  'XYM',
#  'LN',
#  'AMP',
#  'SRM',
#  'VGX',
#  'STORJ',
#  'SYN1',
#  'ONT',
#  'SAFEMOON',
#  'WAXP',
#  'SAFE1',
#  'AUDIO',
#  'GLMR',
#  'ERG',
#  'SC',
#  'POLY',
#  'IMX1',
#  'MXC',
#  'ZEN',
#  'XCH',
#  'LUSD',
#  'CHSB',
#  'ABBC',
#  'SCRT',
#  'CSPR',
#  'SXP',
#  'UMA',
#  'WOO',
#  'HUSD',
#  'PLA3',
#  'PUNDIX',
#  'NFT1',
#  'DGB',
#  'DAO',
#  'SLP',
#  'SKL',
#  'VVS',
#  'ELON',
#  'CKB',
#  'ASTR',
#  'EPS1',
#  'SUSHI',
#  'CVC',
#  'BABYDOGE',
#  'MED',
#  'EWT',
#  'KEEP',
#  'HUM',
#  'UOS',
#  'EURS',
#  'LSK',
#  'SSV',
#  'INJ',
#  'RNDR',
#  'BTCST',
#  'MAID',
#  'ACA1',
#  'SYS',
#  'PLTC',
#  'CEEK',
#  'PEOPLE',
#  'SPELL',
#  'CELR',
#  'COTI',
#  'REQ',
#  'REN',
#  'VLX',
#  'NU',
#  'XNO',
#  'ONG1',
#  'MVL',
#  'CFG',
#  'METIS',
#  'WVLX',
#  'USDX2',
#  'VUSDC',
#  'DLC2',
#  'LOOKS',
#  'RACA',
#  'AVINOC',
#  'ORBS',
#  'FX',
#  'TRIBE',
#  'ARDR',
#  'RLC',
#  'SNT',
#  'RKN',
#  'UQC',
#  'OCEAN',
#  'REEF',
#  'POWR',
#  'WIN',
#  'XYO',
#  'HXRO',
#  'PROM',
#  'NMR',
#  'DENT']
