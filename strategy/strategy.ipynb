# %%
from libraries import *
engine = create_engine('sqlite:///../dataset/crypto_data.db')
ticker_list = pd.read_sql('ticker_list',con=engine)
ticker_list = ticker_list.symbol.to_list()
ticker_list
# Out:
# ['BTC-USD',
#  'ETH-USD',
#  'USDT-USD',
#  'USDC-USD',
#  'BNB-USD',
#  'XRP-USD',
#  'BUSD-USD',
#  'ADA-USD',
#  'SOL-USD',
#  'DOGE-USD',
#  'DOT-USD',
#  'DAI-USD',
#  'MATIC-USD',
#  'SHIB-USD',
#  'WTRX-USD',
#  'TRX-USD',
#  'HEX-USD',
#  'AVAX-USD',
#  'WBTC-USD',
#  'STETH-USD',
#  'UNI1-USD',
#  'YOUC-USD',
#  'LEO-USD',
#  'ATOM-USD',
#  'ETC-USD',
#  'LTC-USD',
#  'LINK-USD',
#  'FTT-USD',
#  'XLM-USD',
#  'CRO-USD',
#  'NEAR-USD',
#  'ALGO-USD',
#  'XMR-USD',
#  'BCH-USD',
#  'BTCB-USD',
#  'FLOW-USD',
#  'APE3-USD',
#  'VET-USD',
#  'FIL-USD',
#  'XCN1-USD',
#  'TONCOIN-USD',
#  'ICP-USD',
#  'CHZ-USD',
#  'LUNA1-USD',
#  'HBAR-USD',
#  'XTZ-USD',
#  'QNT-USD',
#  'SAND-USD',
#  'FRAX-USD',
#  'MANA-USD',
#  'EOS-USD',
#  'WBNB-USD',
#  'THETA-USD',
#  'EGLD-USD',
#  'AXS-USD',
#  'AAVE-USD',
#  'TUSD-USD',
#  'BIT1-USD',
#  'BSV-USD',
#  'USDP-USD',
#  'OKB-USD',
#  'ZEC-USD',
#  'KCS-USD',
#  'MIOTA-USD',
#  'BTT-USD',
#  'XEC-USD',
#  'BTT2-USD',
#  'HBTC-USD',
# ...

# %%
df = pd.read_sql('BTC-USD',con=engine)
df
# Out:
#              Open          High           Low         Close     Adj Close  \
# 0    58706.847656  59266.359375  55679.839844  56289.289062  56289.289062
# 1    56304.554688  57875.515625  55632.761719  57569.074219  57569.074219
# 2    57565.851562  57803.066406  55964.222656  56280.425781  56280.425781
# 3    57165.417969  59367.968750  57146.683594  57274.679688  57274.679688
# 4    58960.285156  59183.480469  53569.765625  53569.765625  53569.765625
# ..            ...           ...           ...           ...           ...
# 726  60887.652344  61645.523438  59164.468750  61553.617188  61553.617188
# 727  61548.804688  62614.660156  60012.757812  62026.078125  62026.078125
# 728  62043.164062  64434.535156  61622.933594  64261.992188  64261.992188
# 729  64284.585938  66930.390625  63610.675781  65992.835938  65992.835938
# 730  66002.234375  66600.546875  62117.410156  62210.171875  62210.171875
#
#           Volume   Datatime
# 0    35036121783 2021-11-22
# ...

# %%
symbol_str = 'BTC-USD ETH-USD'
data = yf.download(
            tickers = symbol_str, 
            period = '2y', 
            interval = '1d', 
            group_by = 'ticker', 
            threads = True,
        )
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df = data['BTC-USD']
# df = data[symbol]
df['Datatime'] = df.index
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-09-24  10248.786133  10771.056641  10231.490234  10760.066406
# 2020-09-25  10761.109375  10777.696289  10578.914062  10692.716797
# 2020-09-26  10695.575195  10772.999023  10667.281250  10750.723633
# 2020-09-27  10746.892578  10803.976562  10622.921875  10775.269531
# 2020-09-28  10776.613281  10945.347656  10703.893555  10709.652344
# ...                  ...           ...           ...           ...
# 2022-09-20  19545.591797  19602.457031  18813.455078  18890.789062
# 2022-09-21  18891.283203  19674.630859  18290.314453  18547.400391
# 2022-09-22  18534.650391  19456.910156  18415.591797  19413.550781
# 2022-09-23  19412.400391  19464.671875  18617.552734  19297.638672
# 2022-09-24  19303.080078  19303.679688  18973.031250  19091.501953
#
#                Adj Close       Volume
# Date
# 2020-09-24  10760.066406  47144380902
# 2020-09-25  10692.716797  39348590957
# ...
